# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
from scipy import stats
from sklearn import metrics
import os

# %%
data_ebay = pd.read_csv("/Users/armeniphone/Desktop/To use in final project/ebay_diamonds.csv")
data_ebay.head()
# Out:
#          itemId                                              title  \
# 0  323548419594  10K Yellow Gold 1.5mm-4mm Laser Diamond Cut Ro...
# 1  141731110269  925 Sterling Silver Diamond Cut Rope Chain Nec...
# 2  192338788722  10K Yellow Gold 2mm-7mm Diamond Cut Rope Chain...
# 3  112606615635  14K Yellow Gold Diamond Cut Rope Chain Necklac...
# 4  143037345050  Real Solid Sterling Silver Diamond Cut Rope Ch...
#
#         primaryCategory country sellingState  watchCount      condition  \
# 0  Necklaces & Pendants      US       Active         NaN  New with tags
# 1  Necklaces & Pendants      US       Active         NaN  New with tags
# 2  Necklaces & Pendants      US       Active         NaN  New with tags
# 3  Necklaces & Pendants      US       Active         NaN  New with tags
# 4  Necklaces & Pendants      US       Active         NaN  New with tags
#
#   sellingStatus._currencyId  sellingStatus.value
# 0                       USD                56.98
# ...

# %%
data_ebay = data_ebay.drop('watchCount', axis=1)

# %%
data_ebay
# Out:
#             itemId                                              title  \
# 0     323548419594  10K Yellow Gold 1.5mm-4mm Laser Diamond Cut Ro...
# 1     141731110269  925 Sterling Silver Diamond Cut Rope Chain Nec...
# 2     192338788722  10K Yellow Gold 2mm-7mm Diamond Cut Rope Chain...
# 3     112606615635  14K Yellow Gold Diamond Cut Rope Chain Necklac...
# 4     143037345050  Real Solid Sterling Silver Diamond Cut Rope Ch...
# ...            ...                                                ...
# 4995  145146087121  Simulated Diamond 2 Ct Round Cut PAW Print Pen...
# 4996  163773700915  Classic Diamond Quilted Nylon Jacket Water Res...
# 4997  165786120342  18K Solid Gold Natural Diamond Pendant Necklac...
# 4998  171778166653  For 07-14 Chevy Suburban Tahoe Avalanche 1500 ...
# 4999  175192871565  Diamond Stitching Golf Cart Seat Cover Black F...
#
#              primaryCategory country sellingState         condition  \
# ...

# %%
data_ebay.to_csv('data_ebay_no_watchcount.csv', index=False)
